# %%
import os
import google_auth_oauthlib.flow
import googleapiclient.discovery
import googleapiclient.errors
from google.oauth2.credentials import Credentials
from google.auth.exceptions import GoogleAuthError

# Scopes for YouTube Data API
SCOPES = ["https://www.googleapis.com/auth/youtube.force-ssl"]

def main():
    # OAuth 2.0 authentication
    os.environ["OAUTHLIB_INSECURE_TRANSPORT"] = "1"
    token_file = "token.json"
    client_secrets_file = "client_secret_1079710896544-smq0icm3dq0568err0a4ltr6ug5bq4gg.apps.googleusercontent.com.json"

    creds = None

    # Load credentials from token.json if it exists
    if os.path.exists(token_file):
        try:
            creds = Credentials.from_authorized_user_file(token_file, SCOPES)
            print("Credentials loaded from token.json")
        except GoogleAuthError as e:
            print(f"Error loading credentials: {e}")

    # If no valid credentials, authenticate the user
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            try:
                creds.refresh(Request())
                print("Credentials refreshed.")
            except Exception as e:
                print(f"Error refreshing credentials: {e}")
        else:
            print("No valid credentials. Starting authentication flow.")
            flow = google_auth_oauthlib.flow.InstalledAppFlow.from_client_secrets_file(
                client_secrets_file, SCOPES)

            credentials = flow.run_local_server(port=8080, open_browser=True)

            # Save the credentials to token.json
            with open(token_file, "w") as token:
                token.write(credentials.to_json())
                print("Credentials saved to token.json")

    # Build the YouTube API client
    youtube = googleapiclient.discovery.build(
        "youtube", "v3", credentials=creds)

    # Specify the playlist ID and video ID
    playlist_id = "PLwo-0bCBnS8RxB0CQubjAaPMccrGRU12U"
    video_id = "kG26qxHoMsM"

    # Insert the video into the playlist
    try:
        request = youtube.playlistItems().insert(
            part="snippet",
            body={
                "snippet": {
                    "playlistId": playlist_id,
                    "resourceId": {
                        "kind": "youtube#video",
                        "videoId": video_id
                    }
                }
            }
        )
        
        response = request.execute()

        print(f"Added video {video_id} to playlist {playlist_id}.")
        print(response)
    except googleapiclient.errors.HttpError as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    main()
# Out:
# No valid credentials. Starting authentication flow.
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=1079710896544-smq0icm3dq0568err0a4ltr6ug5bq4gg.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fyoutube.force-ssl&state=boO7K1DjY4NR2mGwmqqA9EmXnqcZ0b&access_type=offline
# Credentials saved to token.json
# ---------------------------------------------------------------------------
# RefreshError                              Traceback (most recent call last)
# Cell In[1], line 77
#      74         print(f"An error occurred: {e}")
#      76 if __name__ == "__main__":
# ---> 77     main()
#
# Cell In[1], line 69, in main()
#      56 try:
#      57     request = youtube.playlistItems().insert(
#      58         part="snippet",
#      59         body={
#    (...)
#      67         }
#      68     )
# ---> 69     response = request.execute()
# ...

# %%
import os
import json
from google_auth_oauthlib.flow import InstalledAppFlow
from google.oauth2.credentials import Credentials
from googleapiclient.discovery import build
from google.auth.exceptions import GoogleAuthError

# Scopes for YouTube Data API
SCOPES = ["https://www.googleapis.com/auth/youtube.force-ssl"]

def main():
    # OAuth 2.0 authentication
    os.environ["OAUTHLIB_INSECURE_TRANSPORT"] = "1"
    
    # Path to your client secret JSON file
    client_secrets_file = "client_secret_1079710896544-smq0icm3dq0568err0a4ltr6ug5bq4gg.apps.googleusercontent.com.json"

    # Create a flow instance for OAuth 2.0 authorization
    flow = google_auth_oauthlib.flow.InstalledAppFlow.from_client_secrets_file(
        client_secrets_file, SCOPES)
    
    redirect_uri = flow.redirect_uri
    print(f"Redirect URI: {redirect_uri}")
    
    credentials = flow.run_local_server(port=8080, open_browser=True)  # Use run_local_server instead of run_console

    # Build the YouTube API client
    youtube = googleapiclient.discovery.build(
        "youtube", "v3", credentials=credentials)

    # Specify the playlist ID and video ID
    playlist_id = "PLwo-0bCBnS8RxB0CQubjAaPMccrGRU12U"
    video_id = "kG26qxHoMsM"

    # Insert the video into the playlist
    request = youtube.playlistItems().insert(
        part="snippet",
        body={
            "snippet": {
                "playlistId": playlist_id,
                "resourceId": {
                    "kind": "youtube#video",
                    "videoId": video_id
                }
            }
        }
    )
    response = request.execute()

    print(f"Added video {video_id} to playlist {playlist_id}.")
    print(response)

if __name__ == "__main__":
    main()
